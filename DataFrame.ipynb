# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

# %%
website='https://www.nfl.com/standings'
import webbrowser
webbrowser.open(website)
# Out:
# True

# %%
frame=pd.read_clipboard()

# %%
frame
# Out:
#          AFC     East  Team    W      L      T  Arrow     in   down  \
# 0    Buffalo     None   NaN  NaN    NaN    NaN    NaN   None   None
# 1      Bills     None   NaN  NaN    NaN    NaN    NaN   None   None
# 2          3        0   0.0  1.0   66.0   47.0   19.0  1-0-0  2-0-0
# 3        New  England   NaN  NaN    NaN    NaN    NaN   None   None
# 4   Patriots     None   NaN  NaN    NaN    NaN    NaN   None   None
# 5          3        0   0.0  1.0  106.0   17.0   89.0  2-0-0  1-0-0
# 6        New     York   NaN  NaN    NaN    NaN    NaN   None   None
# 7       Jets     None   NaN  NaN    NaN    NaN    NaN   None   None
# 8          0        3   0.0  0.0   33.0   70.0  -37.0  0-2-0  0-1-0
# 9      Miami     None   NaN  NaN    NaN    NaN    NaN   None   None
# 10  Dolphins     None   NaN  NaN    NaN    NaN    NaN   None   None
# 11         0        3   0.0  0.0   16.0  133.0 -117.0  0-2-0  0-1-0
#
#    directionPCT  ...  Home   Road  Div Pct Conf Pct.1  Non-Conf  Streak  Last  \
# ...

# %%
frame.columns
# Out:
# Index([u'AFC', u'East', u'Team', u'W', u'L', u'T', u'Arrow', u'in', u'down',
#        u'directionPCT', u'PF', u'PA', u'Net', u'Pts', u'Home', u'Road', u'Div',
#        u'Pct', u'Conf', u'Pct.1', u'Non-Conf', u'Streak', u'Last', u'5'],
#       dtype='object')

# %%
frame['Team']
# Out:
# 0     NaN
# 1     NaN
# 2     0.0
# 3     NaN
# 4     NaN
# 5     0.0
# 6     NaN
# 7     NaN
# 8     0.0
# 9     NaN
# 10    NaN
# 11    0.0
# Name: Team, dtype: float64

# %% [markdown]
# ## creating a new dataframe from existing data frame (means taking data from existing frame)

# %%
# DataFrame(name_of_existing_dataframe,columns=[name_of_columns])
new_frame=DataFrame(frame,columns=['AFC','Team','Arrow','down'])
new_frame
# Out:
#          AFC  Team  Arrow   down
# 0    Buffalo   NaN    NaN   None
# 1      Bills   NaN    NaN   None
# 2          3   0.0   19.0  2-0-0
# 3        New   NaN    NaN   None
# 4   Patriots   NaN    NaN   None
# 5          3   0.0   89.0  1-0-0
# 6        New   NaN    NaN   None
# 7       Jets   NaN    NaN   None
# 8          0   0.0  -37.0  0-1-0
# 9      Miami   NaN    NaN   None
# 10  Dolphins   NaN    NaN   None
# 11         0   0.0 -117.0  0-1-0

# %% [markdown]
# ## retrieving rows using .head(n)=gives first n rows and .tail(p)=gives last p rows

# %%
frame.head(5)
# Out:
#         AFC     East  Team    W     L     T  Arrow     in   down directionPCT  \
# 0   Buffalo     None   NaN  NaN   NaN   NaN    NaN   None   None         None
# 1     Bills     None   NaN  NaN   NaN   NaN    NaN   None   None         None
# 2         3        0   0.0  1.0  66.0  47.0   19.0  1-0-0  2-0-0        1-0-0
# 3       New  England   NaN  NaN   NaN   NaN    NaN   None   None         None
# 4  Patriots     None   NaN  NaN   NaN   NaN    NaN   None   None         None
#
#    ...  Home   Road  Div Pct Conf Pct.1  Non-Conf  Streak  Last   5
# 0  ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 1  ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 2  ...    3W  3-0-0  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 3  ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 4  ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
#
# [5 rows x 24 columns]

# %%
frame.tail(5)
# Out:
#          AFC  East  Team    W     L      T  Arrow     in   down directionPCT  \
# 7       Jets  None   NaN  NaN   NaN    NaN    NaN   None   None         None
# 8          0     3   0.0  0.0  33.0   70.0  -37.0  0-2-0  0-1-0        0-2-0
# 9      Miami  None   NaN  NaN   NaN    NaN    NaN   None   None         None
# 10  Dolphins  None   NaN  NaN   NaN    NaN    NaN   None   None         None
# 11         0     3   0.0  0.0  16.0  133.0 -117.0  0-2-0  0-1-0        0-1-0
#
#     ...  Home   Road  Div Pct Conf Pct.1  Non-Conf  Streak  Last   5
# 7   ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 8   ...    3L  0-3-0  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 9   ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 10  ...  None   None  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
# 11  ...    3L  0-3-0  NaN NaN  NaN   NaN       NaN     NaN   NaN NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## to restrieve the row of perticule index use .ix or .iloc or .loc[nth row]

# %%
# retrieving 2nd row
frame.loc[2]
# Out:
# AFC                 3
# East                0
# Team                0
# W                   1
# L                  66
# T                  47
# Arrow              19
# in              1-0-0
# down            2-0-0
# directionPCT    1-0-0
# PF                  1
# PA              2-0-0
# Net                 1
# Pts             1-0-0
# Home               3W
# Road            3-0-0
# Div               NaN
# Pct               NaN
# Conf              NaN
# Pct.1             NaN
# Non-Conf          NaN
# Streak            NaN
# Last              NaN
# 5                 NaN
# Name: 2, dtype: object

# %% [markdown]
# ## adding new columns to table

# %%
DataFrame(frame,columns=['first_name','last_name','index'])
# Out:
#    first_name last_name  index
# 0      gaurav     kumar    NaN
# 1         NaN       NaN    NaN
# 2         NaN       NaN    NaN
# 3         NaN       NaN    NaN
# 4     saurabh     kumar    NaN
# 5         NaN       NaN    NaN
# 6         NaN       NaN    NaN
# 7         NaN       NaN    NaN
# 8         NaN       NaN    NaN
# 9         NaN       NaN    NaN
# 10        NaN       NaN    NaN
# 11        NaN       NaN    NaN

# %% [markdown]
# ## assigning values to new added columns or existing columns

# %%
frame['first_name']='saurabh'
frame['last_name']='kumar'
frame['index']=np.arange(12)

# %%
frame
# Out:
#          AFC     East  Team    W      L      T  Arrow     in   down  \
# 0    Buffalo     None   NaN  NaN    NaN    NaN    NaN   None   None
# 1      Bills     None   NaN  NaN    NaN    NaN    NaN   None   None
# 2          3        0   0.0  1.0   66.0   47.0   19.0  1-0-0  2-0-0
# 3        New  England   NaN  NaN    NaN    NaN    NaN   None   None
# 4   Patriots     None   NaN  NaN    NaN    NaN    NaN   None   None
# 5          3        0   0.0  1.0  106.0   17.0   89.0  2-0-0  1-0-0
# 6        New     York   NaN  NaN    NaN    NaN    NaN   None   None
# 7       Jets     None   NaN  NaN    NaN    NaN    NaN   None   None
# 8          0        3   0.0  0.0   33.0   70.0  -37.0  0-2-0  0-1-0
# 9      Miami     None   NaN  NaN    NaN    NaN    NaN   None   None
# 10  Dolphins     None   NaN  NaN    NaN    NaN    NaN   None   None
# 11         0        3   0.0  0.0   16.0  133.0 -117.0  0-2-0  0-1-0
#
#    directionPCT  ...  Pct Conf  Pct.1 Non-Conf Streak Last   5  first_name  \
# ...

# %% [markdown]
# ## add data in any column from series in a perticular row

# %%
first_name=Series(['saurabh','gaurav'],index=[4,0])
last_name=Series(['kumar','kumar'],index=[4,0])

# %%
first_name

# %%
last_name

# %%
frame['first_name']=first_name
frame['last_name']=last_name

# %%
frame
# Out:
#          AFC     East  Team    W      L      T  Arrow     in   down  \
# 0    Buffalo     None   NaN  NaN    NaN    NaN    NaN   None   None
# 1      Bills     None   NaN  NaN    NaN    NaN    NaN   None   None
# 2          3        0   0.0  1.0   66.0   47.0   19.0  1-0-0  2-0-0
# 3        New  England   NaN  NaN    NaN    NaN    NaN   None   None
# 4   Patriots     None   NaN  NaN    NaN    NaN    NaN   None   None
# 5          3        0   0.0  1.0  106.0   17.0   89.0  2-0-0  1-0-0
# 6        New     York   NaN  NaN    NaN    NaN    NaN   None   None
# 7       Jets     None   NaN  NaN    NaN    NaN    NaN   None   None
# 8          0        3   0.0  0.0   33.0   70.0  -37.0  0-2-0  0-1-0
# 9      Miami     None   NaN  NaN    NaN    NaN    NaN   None   None
# 10  Dolphins     None   NaN  NaN    NaN    NaN    NaN   None   None
# 11         0        3   0.0  0.0   16.0  133.0 -117.0  0-2-0  0-1-0
#
#    directionPCT  ...  Div Pct  Conf Pct.1 Non-Conf Streak  Last   5  \
# ...

# %%
frame
# Out:
#          AFC     East  Team    W      L      T  Arrow     in   down  \
# 0    Buffalo     None   NaN  NaN    NaN    NaN    NaN   None   None
# 1      Bills     None   NaN  NaN    NaN    NaN    NaN   None   None
# 2          3        0   0.0  1.0   66.0   47.0   19.0  1-0-0  2-0-0
# 3        New  England   NaN  NaN    NaN    NaN    NaN   None   None
# 4   Patriots     None   NaN  NaN    NaN    NaN    NaN   None   None
# 5          3        0   0.0  1.0  106.0   17.0   89.0  2-0-0  1-0-0
# 6        New     York   NaN  NaN    NaN    NaN    NaN   None   None
# 7       Jets     None   NaN  NaN    NaN    NaN    NaN   None   None
# 8          0        3   0.0  0.0   33.0   70.0  -37.0  0-2-0  0-1-0
# 9      Miami     None   NaN  NaN    NaN    NaN    NaN   None   None
# 10  Dolphins     None   NaN  NaN    NaN    NaN    NaN   None   None
# 11         0        3   0.0  0.0   16.0  133.0 -117.0  0-2-0  0-1-0
#
#    directionPCT  ...  Div Pct  Conf Pct.1 Non-Conf Streak  Last   5  \
# ...

# %% [markdown]
# ## construct a dataframe just by passing dictionary through DataFrame

# %%
#construct a dictionary
new_dict={'city':['India','USA','Russia'],'pop':[1232131,32131231,31231231]}
new_dict
# Out:
# {'city': ['India', 'USA', 'Russia'], 'pop': [1232131, 32131231, 31231231]}

# %%
city_frame=DataFrame(new_dict)
city_frame
# Out:
#      city       pop
# 0   India   1232131
# 1     USA  32131231
# 2  Russia  31231231

# %% [markdown]
# ## delete a column

# %%
del frame['Streak']

# %%
frame
# Out:
#          AFC     East  Team    W      L      T  Arrow     in   down  \
# 0    Buffalo     None   NaN  NaN    NaN    NaN    NaN   None   None
# 1      Bills     None   NaN  NaN    NaN    NaN    NaN   None   None
# 2          3        0   0.0  1.0   66.0   47.0   19.0  1-0-0  2-0-0
# 3        New  England   NaN  NaN    NaN    NaN    NaN   None   None
# 4   Patriots     None   NaN  NaN    NaN    NaN    NaN   None   None
# 5          3        0   0.0  1.0  106.0   17.0   89.0  2-0-0  1-0-0
# 6        New     York   NaN  NaN    NaN    NaN    NaN   None   None
# 7       Jets     None   NaN  NaN    NaN    NaN    NaN   None   None
# 8          0        3   0.0  0.0   33.0   70.0  -37.0  0-2-0  0-1-0
# 9      Miami     None   NaN  NaN    NaN    NaN    NaN   None   None
# 10  Dolphins     None   NaN  NaN    NaN    NaN    NaN   None   None
# 11         0        3   0.0  0.0   16.0  133.0 -117.0  0-2-0  0-1-0
#
#    directionPCT  ...   Road Div  Pct Conf Pct.1 Non-Conf  Last   5  \
# ...

# %%
import webbrowser
website='https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
